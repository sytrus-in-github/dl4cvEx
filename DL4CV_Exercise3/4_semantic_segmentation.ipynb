# %% [markdown]
# # PyTorch semantic segmentation
# For this last exercise you are going to work on a new computer vision task called semantic segmentation where not an entire image but each pixel is classified. This means in comparison to image classification your model outputs not a single class but a segmentation with the same size as the input image. Since you have already learned a lot in the past exercises and you are now familiar with the basics of PyTorch the model design and architecture as well as the training is totally up to you. We only provide you with the train and validation dataset and recommend you to look for PyTorch implementations and finetuning weights of famous semantic segmentation networks.
#
# <img src="https://camo.githubusercontent.com/d10b897e15344334e449104a824aff6c29125dc2/687474703a2f2f63616c76696e2e696e662e65642e61632e756b2f77702d636f6e74656e742f75706c6f6164732f646174612f636f636f7374756666646174617365742f636f636f73747566662d6578616d706c65732e706e67">

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
from torch.autograd import Variable

from dl4cv.classifiers.segmentation_network import SegmentationNetwork
from dl4cv.data_utils import SegmentationData

#torch.set_default_tensor_type('torch.FloatTensor')

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Train and validation data
#
# Download the dataset with the `datasets/get_segmentation_dataset.sh` script and make yourself familiar with it. Look at the labels described in `datasets/segmentation_data/info.html` and note the label `unlabeled`. Pixels with the label `unlabeled` should neither be considered in your loss nor the accuracy.

# %%
train_data = SegmentationData(root='datasets/segmentation_data',
                              image_list='train.txt')

val_data = SegmentationData(root='datasets/segmentation_data',
                            image_list='val.txt')

# %%
print("Train size: %i" % len(train_data))
print("Validation size: %i" % len(val_data))

img, target = train_data[1]
print("Img size: " + str(img.size()))
print("Segmentation size: " + str(target.size()))
plt.figure(figsize=(4,4))
plt.imshow(img.numpy().transpose(1,2,0))
plt.show()
plt.figure(figsize=(4,4))
plt.imshow(target.numpy())
plt.show()
# Out:
# Train size: 276
# Validation size: 59
# Img size: torch.Size([3, 240, 240])
# Segmentation size: torch.Size([240, 240])

# %% [markdown]
# ## Train your network
# Implement your network architecture in `classifiers.segmentation_network.py` and adapt your `Solver` to process segmentation labels. Think about finetuning a model instead of training from scratch. If you are not equipped with a CUDA GPU test your model locally and then finish training on the computers in our lab.

# %%
from dl4cv.classifiers.segmentation_network import SegmentationNetwork
from dl4cv.classifiers.solver import Solver

############################################################################
#                             YOUR CODE                                    #
############################################################################
train_loader = torch.utils.data.DataLoader(train_data, batch_size=1, shuffle=True, num_workers=1)
val_loader = torch.utils.data.DataLoader(val_data, batch_size=1, shuffle=False, num_workers=1)

import torch.nn.functional as F

def CrossEntropy2d():
    def wrap(inputs, targets, weight=None, pixel_average=True):
        n, c, h, w = inputs.size()

        inputs = inputs.transpose(1, 2).transpose(2, 3).contiguous()
        inputs = inputs[targets.view(n, h, w, 1).repeat(1, 1, 1, c) >= 0].view(-1, c)

        targets_mask = targets >= 0
        targets = targets[targets_mask]
        
        #loss = F.nll_loss(F.log_softmax(input), target, weight=weight, size_average=False)
        loss = F.cross_entropy(inputs, targets, weight=weight, size_average=False)
        if pixel_average:
            loss /= targets_mask.data.sum()
        return loss
    return wrap

model = SegmentationNetwork()
#model.init_alexnet_weight()
solver = Solver(optim_args={"lr": 1e-4, "weight_decay": 0.001}, loss_func=CrossEntropy2d)
solver.train(model, train_loader, val_loader, log_nth=5, num_epochs=4, in_cuda=True)
# Out:
# START TRAIN.
# [Iteration 0/276] TRAIN loss: 3.6307926178
# [Iteration 5/276] TRAIN loss: 3.23085045815
# [Iteration 10/276] TRAIN loss: 3.28536295891
# [Iteration 15/276] TRAIN loss: 3.2217862606
# [Iteration 20/276] TRAIN loss: 3.25099372864
# [Iteration 25/276] TRAIN loss: 3.12438869476
# [Iteration 30/276] TRAIN loss: 3.02875828743
# [Iteration 35/276] TRAIN loss: 3.10688328743
# [Iteration 40/276] TRAIN loss: 3.02638959885
# [Iteration 45/276] TRAIN loss: 3.05365085602
# [Iteration 50/276] TRAIN loss: 2.99410104752
# [Iteration 55/276] TRAIN loss: 2.92737412453
# [Iteration 60/276] TRAIN loss: 2.89098000526
# [Iteration 65/276] TRAIN loss: 2.89119434357
# [Iteration 70/276] TRAIN loss: 2.88763546944
# [Iteration 75/276] TRAIN loss: 2.84223294258
# [Iteration 80/276] TRAIN loss: 2.82777523994
# [Iteration 85/276] TRAIN loss: 2.80617928505
# [Iteration 90/276] TRAIN loss: 2.75393939018
# [Iteration 95/276] TRAIN loss: 2.70437645912
# [Iteration 100/276] TRAIN loss: 2.68969702721
# [Iteration 105/276] TRAIN loss: 2.68075966835
# [Iteration 110/276] TRAIN loss: 2.66476655006
# [Iteration 115/276] TRAIN loss: 2.64160871506
# [Iteration 120/276] TRAIN loss: 2.62052559853
# [Iteration 125/276] TRAIN loss: 2.60042190552
# [Iteration 130/276] TRAIN loss: 2.57934570312
# [Iteration 135/276] TRAIN loss: 2.58551621437
# [Iteration 140/276] TRAIN loss: 2.57637286186
# [Iteration 145/276] TRAIN loss: 2.57086014748
# [Iteration 150/276] TRAIN loss: 2.56054639816
# [Iteration 155/276] TRAIN loss: 2.53909850121
# [Iteration 160/276] TRAIN loss: 2.53163695335
# [Iteration 165/276] TRAIN loss: 2.51468253136
# [Iteration 170/276] TRAIN loss: 2.5006082058
# [Iteration 175/276] TRAIN loss: 2.48896956444
# [Iteration 180/276] TRAIN loss: 2.48107886314
# [Iteration 185/276] TRAIN loss: 2.45460653305
# [Iteration 190/276] TRAIN loss: 2.43260908127
# [Iteration 195/276] TRAIN loss: 2.42889857292
# [Iteration 200/276] TRAIN loss: 2.40504932404
# [Iteration 205/276] TRAIN loss: 2.38705897331
# [Iteration 210/276] TRAIN loss: 2.37111473083
# [Iteration 215/276] TRAIN loss: 2.36190462112
# [Iteration 220/276] TRAIN loss: 2.35326814651
# [Iteration 225/276] TRAIN loss: 2.3234500885
# [Iteration 230/276] TRAIN loss: 2.30679392815
# [Iteration 235/276] TRAIN loss: 2.30009746552
# [Iteration 240/276] TRAIN loss: 2.28188037872
# [Iteration 245/276] TRAIN loss: 2.27406096458
# [Iteration 250/276] TRAIN loss: 2.25878167152
# [Iteration 255/276] TRAIN loss: 2.26044273376
# [Iteration 260/276] TRAIN loss: 2.25506091118
# [Iteration 265/276] TRAIN loss: 2.253698349
# [Iteration 270/276] TRAIN loss: 2.25960707664
# [Iteration 275/276] TRAIN loss: 2.24822640419
# [Epoch 1/5] TRAIN acc/loss: 0.374476219678/2.24822640419
# [Epoch 1/5] VAL acc/loss: 0.642204898535/1.2916148901
# [Iteration 0/276] TRAIN loss: 2.21064019203
# [Iteration 5/276] TRAIN loss: 1.62969779968
# [Iteration 10/276] TRAIN loss: 1.51152598858
# [Iteration 15/276] TRAIN loss: 1.55897021294
# [Iteration 20/276] TRAIN loss: 1.43568098545
# [Iteration 25/276] TRAIN loss: 1.37531793118
# [Iteration 30/276] TRAIN loss: 1.35508608818
# [Iteration 35/276] TRAIN loss: 1.37331795692
# [Iteration 40/276] TRAIN loss: 1.35244643688
# [Iteration 45/276] TRAIN loss: 1.35913741589
# [Iteration 50/276] TRAIN loss: 1.33961188793
# [Iteration 55/276] TRAIN loss: 1.34646832943
# [Iteration 60/276] TRAIN loss: 1.32897126675
# [Iteration 65/276] TRAIN loss: 1.39020144939
# [Iteration 70/276] TRAIN loss: 1.38679277897
# [Iteration 75/276] TRAIN loss: 1.39615106583
# [Iteration 80/276] TRAIN loss: 1.36002266407
# [Iteration 85/276] TRAIN loss: 1.37211120129
# [Iteration 90/276] TRAIN loss: 1.35263442993
# [Iteration 95/276] TRAIN loss: 1.33907139301
# [Iteration 100/276] TRAIN loss: 1.33618152142
# [Iteration 105/276] TRAIN loss: 1.33710992336
# [Iteration 110/276] TRAIN loss: 1.31039083004
# [Iteration 115/276] TRAIN loss: 1.30335128307
# [Iteration 120/276] TRAIN loss: 1.30223298073
# [Iteration 125/276] TRAIN loss: 1.28884994984
# [Iteration 130/276] TRAIN loss: 1.28904175758
# [Iteration 135/276] TRAIN loss: 1.27439785004
# [Iteration 140/276] TRAIN loss: 1.26527440548
# [Iteration 145/276] TRAIN loss: 1.26750707626
# [Iteration 150/276] TRAIN loss: 1.29237258434
# [Iteration 155/276] TRAIN loss: 1.29729664326
# [Iteration 160/276] TRAIN loss: 1.30374324322
# [Iteration 165/276] TRAIN loss: 1.30107021332
# [Iteration 170/276] TRAIN loss: 1.29383277893
# [Iteration 175/276] TRAIN loss: 1.28180408478
# [Iteration 180/276] TRAIN loss: 1.28077745438
# [Iteration 185/276] TRAIN loss: 1.2749427557
# [Iteration 190/276] TRAIN loss: 1.25578761101
# [Iteration 195/276] TRAIN loss: 1.26024532318
# [Iteration 200/276] TRAIN loss: 1.2544542551
# [Iteration 205/276] TRAIN loss: 1.25276422501
# [Iteration 210/276] TRAIN loss: 1.24682235718
# [Iteration 215/276] TRAIN loss: 1.2487616539
# [Iteration 220/276] TRAIN loss: 1.24000597
# [Iteration 225/276] TRAIN loss: 1.24388754368
# [Iteration 230/276] TRAIN loss: 1.23598968983
# [Iteration 235/276] TRAIN loss: 1.25055074692
# [Iteration 240/276] TRAIN loss: 1.24125802517
# [Iteration 245/276] TRAIN loss: 1.2457652092
# [Iteration 250/276] TRAIN loss: 1.24472105503
# [Iteration 255/276] TRAIN loss: 1.24958491325
# [Iteration 260/276] TRAIN loss: 1.24599480629
# [Iteration 265/276] TRAIN loss: 1.24063336849
# [Iteration 270/276] TRAIN loss: 1.23874115944
# [Iteration 275/276] TRAIN loss: 1.23591852188
# [Epoch 2/5] TRAIN acc/loss: 0.683740475605/1.23591852188
# [Epoch 2/5] VAL acc/loss: 0.708321190893/1.01243531704
# [Iteration 0/276] TRAIN loss: 0.612547338009
# [Iteration 5/276] TRAIN loss: 0.683110415936
# [Iteration 10/276] TRAIN loss: 0.634347617626
# [Iteration 15/276] TRAIN loss: 0.702455997467
# [Iteration 20/276] TRAIN loss: 0.689747452736
# [Iteration 25/276] TRAIN loss: 0.758136689663
# [Iteration 30/276] TRAIN loss: 0.799704909325
# [Iteration 35/276] TRAIN loss: 0.821687579155
# [Iteration 40/276] TRAIN loss: 0.78851300478
# [Iteration 45/276] TRAIN loss: 0.824957370758
# [Iteration 50/276] TRAIN loss: 0.812705934048
# [Iteration 55/276] TRAIN loss: 0.805656075478
# [Iteration 60/276] TRAIN loss: 0.816440880299
# [Iteration 65/276] TRAIN loss: 0.834906160831
# [Iteration 70/276] TRAIN loss: 0.851386547089
# [Iteration 75/276] TRAIN loss: 0.824794590473
# [Iteration 80/276] TRAIN loss: 0.823284089565
# [Iteration 85/276] TRAIN loss: 0.795364618301
# [Iteration 90/276] TRAIN loss: 0.778583467007
# [Iteration 95/276] TRAIN loss: 0.76536232233
# [Iteration 100/276] TRAIN loss: 0.785188853741
# [Iteration 105/276] TRAIN loss: 0.793377995491
# [Iteration 110/276] TRAIN loss: 0.793996572495
# [Iteration 115/276] TRAIN loss: 0.784588336945
# [Iteration 120/276] TRAIN loss: 0.770686626434
# [Iteration 125/276] TRAIN loss: 0.766249239445
# [Iteration 130/276] TRAIN loss: 0.764449357986
# [Iteration 135/276] TRAIN loss: 0.757735490799
# [Iteration 140/276] TRAIN loss: 0.76807487011
# [Iteration 145/276] TRAIN loss: 0.767499864101
# [Iteration 150/276] TRAIN loss: 0.770090043545
# [Iteration 155/276] TRAIN loss: 0.764440357685
# [Iteration 160/276] TRAIN loss: 0.752629339695
# [Iteration 165/276] TRAIN loss: 0.745226502419
# [Iteration 170/276] TRAIN loss: 0.739737331867
# [Iteration 175/276] TRAIN loss: 0.748163044453
# [Iteration 180/276] TRAIN loss: 0.750165760517
# [Iteration 185/276] TRAIN loss: 0.749825119972
# [Iteration 190/276] TRAIN loss: 0.745347082615
# [Iteration 195/276] TRAIN loss: 0.75165438652
# [Iteration 200/276] TRAIN loss: 0.759998977184
# [Iteration 205/276] TRAIN loss: 0.751359820366
# [Iteration 210/276] TRAIN loss: 0.749535322189
# [Iteration 215/276] TRAIN loss: 0.744746148586
# [Iteration 220/276] TRAIN loss: 0.749391674995
# [Iteration 225/276] TRAIN loss: 0.745390892029
# [Iteration 230/276] TRAIN loss: 0.744792938232
# [Iteration 235/276] TRAIN loss: 0.742932856083
# [Iteration 240/276] TRAIN loss: 0.735901236534
# [Iteration 245/276] TRAIN loss: 0.733779430389
# [Iteration 250/276] TRAIN loss: 0.734595119953
# [Iteration 255/276] TRAIN loss: 0.740235686302
# [Iteration 260/276] TRAIN loss: 0.736640930176
# [Iteration 265/276] TRAIN loss: 0.734483778477
# [Iteration 270/276] TRAIN loss: 0.7357827425
# [Iteration 275/276] TRAIN loss: 0.73402184248
# [Epoch 3/5] TRAIN acc/loss: 0.83728917081/0.73402184248
# [Epoch 3/5] VAL acc/loss: 0.787765631957/0.805534482002
# [Iteration 0/276] TRAIN loss: 1.46881699562
# [Iteration 5/276] TRAIN loss: 0.522615015507
# [Iteration 10/276] TRAIN loss: 0.426906496286
# [Iteration 15/276] TRAIN loss: 0.509247839451
# [Iteration 20/276] TRAIN loss: 0.471237808466
# [Iteration 25/276] TRAIN loss: 0.47001850605
# [Iteration 30/276] TRAIN loss: 0.541871845722
# [Iteration 35/276] TRAIN loss: 0.595511317253
# [Iteration 40/276] TRAIN loss: 0.565926790237
# [Iteration 45/276] TRAIN loss: 0.571470797062
# [Iteration 50/276] TRAIN loss: 0.563729643822
# [Iteration 55/276] TRAIN loss: 0.548467934132
# [Iteration 60/276] TRAIN loss: 0.549842536449
# [Iteration 65/276] TRAIN loss: 0.552123308182
# [Iteration 70/276] TRAIN loss: 0.561737954617
# [Iteration 75/276] TRAIN loss: 0.562021911144
# [Iteration 80/276] TRAIN loss: 0.543778479099
# [Iteration 85/276] TRAIN loss: 0.529171228409
# [Iteration 90/276] TRAIN loss: 0.531942129135
# [Iteration 95/276] TRAIN loss: 0.516278326511
# [Iteration 100/276] TRAIN loss: 0.518846929073
# [Iteration 105/276] TRAIN loss: 0.528289914131
# [Iteration 110/276] TRAIN loss: 0.524758696556
# [Iteration 115/276] TRAIN loss: 0.528308808804
# [Iteration 120/276] TRAIN loss: 0.517916738987
# [Iteration 125/276] TRAIN loss: 0.519379496574
# [Iteration 130/276] TRAIN loss: 0.525047004223
# [Iteration 135/276] TRAIN loss: 0.517290890217
# [Iteration 140/276] TRAIN loss: 0.517043113708
# [Iteration 145/276] TRAIN loss: 0.515626609325
# [Iteration 150/276] TRAIN loss: 0.519972920418
# [Iteration 155/276] TRAIN loss: 0.518335700035
# [Iteration 160/276] TRAIN loss: 0.512787044048
# [Iteration 165/276] TRAIN loss: 0.50504052639
# [Iteration 170/276] TRAIN loss: 0.498980343342
# [Iteration 175/276] TRAIN loss: 0.495304197073
# [Iteration 180/276] TRAIN loss: 0.493449687958
# [Iteration 185/276] TRAIN loss: 0.487514317036
# [Iteration 190/276] TRAIN loss: 0.479369401932
# [Iteration 195/276] TRAIN loss: 0.473460614681
# [Iteration 200/276] TRAIN loss: 0.473665773869
# [Iteration 205/276] TRAIN loss: 0.476213872433
# [Iteration 210/276] TRAIN loss: 0.469567030668
# [Iteration 215/276] TRAIN loss: 0.468139052391
# [Iteration 220/276] TRAIN loss: 0.465334028006
# [Iteration 225/276] TRAIN loss: 0.473409295082
# [Iteration 230/276] TRAIN loss: 0.46999591589
# [Iteration 235/276] TRAIN loss: 0.46710523963
# [Iteration 240/276] TRAIN loss: 0.465622901917
# [Iteration 245/276] TRAIN loss: 0.462627828121
# [Iteration 250/276] TRAIN loss: 0.468452125788
# [Iteration 255/276] TRAIN loss: 0.467175066471
# [Iteration 260/276] TRAIN loss: 0.465007066727
# [Iteration 265/276] TRAIN loss: 0.466497987509
# [Iteration 270/276] TRAIN loss: 0.465288043022
# [Iteration 275/276] TRAIN loss: 0.465558707714
# [Epoch 4/5] TRAIN acc/loss: 0.914348844918/0.465558707714
# [Epoch 4/5] VAL acc/loss: 0.810187518852/0.747967422009
# [Iteration 0/276] TRAIN loss: 0.205571219325
# [Iteration 5/276] TRAIN loss: 0.211455091834
# [Iteration 10/276] TRAIN loss: 0.235468402505
# [Iteration 15/276] TRAIN loss: 0.307056903839
# [Iteration 20/276] TRAIN loss: 0.319107919931
# [Iteration 25/276] TRAIN loss: 0.304922789335
# [Iteration 30/276] TRAIN loss: 0.313119679689
# [Iteration 35/276] TRAIN loss: 0.304836153984
# [Iteration 40/276] TRAIN loss: 0.314480930567
# [Iteration 45/276] TRAIN loss: 0.296336144209
# [Iteration 50/276] TRAIN loss: 0.303649872541
# [Iteration 55/276] TRAIN loss: 0.304536432028
# [Iteration 60/276] TRAIN loss: 0.302224814892
# [Iteration 65/276] TRAIN loss: 0.303594768047
# [Iteration 70/276] TRAIN loss: 0.303938597441
# [Iteration 75/276] TRAIN loss: 0.298581063747
# [Iteration 80/276] TRAIN loss: 0.304846733809
# [Iteration 85/276] TRAIN loss: 0.304311454296
# [Iteration 90/276] TRAIN loss: 0.303644448519
# [Iteration 95/276] TRAIN loss: 0.297629207373
# [Iteration 100/276] TRAIN loss: 0.292428225279
# [Iteration 105/276] TRAIN loss: 0.29654532671
# [Iteration 110/276] TRAIN loss: 0.295373350382
# [Iteration 115/276] TRAIN loss: 0.294731706381
# [Iteration 120/276] TRAIN loss: 0.293564140797
# [Iteration 125/276] TRAIN loss: 0.290023624897
# [Iteration 130/276] TRAIN loss: 0.287707567215
# [Iteration 135/276] TRAIN loss: 0.294415652752
# [Iteration 140/276] TRAIN loss: 0.310938298702
# [Iteration 145/276] TRAIN loss: 0.309714078903
# [Iteration 150/276] TRAIN loss: 0.315100848675
# [Iteration 155/276] TRAIN loss: 0.317094862461
# [Iteration 160/276] TRAIN loss: 0.329820394516
# [Iteration 165/276] TRAIN loss: 0.331489592791
# [Iteration 170/276] TRAIN loss: 0.33234462142
# [Iteration 175/276] TRAIN loss: 0.327040582895
# [Iteration 180/276] TRAIN loss: 0.331788659096
# [Iteration 185/276] TRAIN loss: 0.326510965824
# [Iteration 190/276] TRAIN loss: 0.325855642557
# [Iteration 195/276] TRAIN loss: 0.321574300528
# [Iteration 200/276] TRAIN loss: 0.31993252039
# [Iteration 205/276] TRAIN loss: 0.321357786655
# [Iteration 210/276] TRAIN loss: 0.317171365023
# [Iteration 215/276] TRAIN loss: 0.316978245974
# [Iteration 220/276] TRAIN loss: 0.317066937685
# [Iteration 225/276] TRAIN loss: 0.315197825432
# [Iteration 230/276] TRAIN loss: 0.313698172569
# [Iteration 235/276] TRAIN loss: 0.313623726368
# [Iteration 240/276] TRAIN loss: 0.314503073692
# [Iteration 245/276] TRAIN loss: 0.311442226171
# [Iteration 250/276] TRAIN loss: 0.318318754435
# [Iteration 255/276] TRAIN loss: 0.321261405945
# [Iteration 260/276] TRAIN loss: 0.318619579077
# [Iteration 265/276] TRAIN loss: 0.319510132074
# [Iteration 270/276] TRAIN loss: 0.317082375288
# [Iteration 275/276] TRAIN loss: 0.316413968801
# [Epoch 5/5] TRAIN acc/loss: 0.948812367015/0.316413968801
# [Epoch 5/5] VAL acc/loss: 0.790486019834/0.77108079195
# FINISH.

# %% [markdown]
# # Test your model
# Since this dataset is very small we only provided you with a validation set.

# %%
test_data = SegmentationData(root='datasets/segmentation_data', image_list='val.txt')
test_loader = torch.utils.data.DataLoader(test_data,
                                          batch_size=1,
                                          shuffle=False,
                                          num_workers=1)

test_scores = []
model.cpu()
model.eval()
for batch in test_loader:
    inputs, labels = Variable(batch[0]), Variable(batch[1])

    outputs = model.forward(inputs)
    _, preds = torch.max(outputs, 1)
    labels_mask = labels >= 0
    test_scores.append(np.mean((preds == labels)[labels_mask].data.numpy()))
    
model.train()
test_acc = np.mean(test_scores)
print(test_acc)
# Out:
# 0.790485699676

# %% [markdown]
# # Visualization

# %%
from dl4cv.data_utils import label_img_to_rgb

img, target, pred = inputs[0].data.numpy(), labels[0].data.numpy(), preds[0].data.numpy()
              
plt.figure(figsize=(4,4))
plt.imshow(img.transpose(1,2,0))
plt.show()
plt.figure(figsize=(4,4))
plt.imshow(label_img_to_rgb(target))
plt.show()
plt.figure(figsize=(4,4))
plt.imshow(label_img_to_rgb(pred))
plt.show()

# %% [markdown]
# ## Save the model
#
# When you are satisfied with your training, save the model for submission.

# %%
model.save("models/segmentation_network.model")
# Out:
# Saving model... models/segmentation_network.model

# %% [markdown]
# ## Scoring function
# We will score the model you have just saved based on the classification accuracy on our test dataset. The scoring function should represent the difficulty of obtaining a good test accuracy and should therefore give 0 points for worse results than random guessing, should be linear in a first regime and exponential beyond that. The onset of exponential growth depends on the problem. In that region you get twice as many points for an additional 10% accuracy.
#
# For this problem we specifically use the following scoring function:
#     $$f(x) = \left\{
# 	\begin{array}{ll}
# 		0  & \mbox{if } x \leq 0.1 \\
# 		100x & \mbox{if } 0.1 < x \leq 0.5 \\
#         \left(\frac{50}{\exp(0.5 \ln(2)/0.1)}\right) \exp(x \ln(2)/0.1) & \mbox{if } 0.5 < x \leq 1
# 	\end{array}
# \right.$$
#
# The function can be plotted in the following cell.

# %%
from dl4cv.data_utils import scoring_function

x = np.linspace(0, 1, num=1000)
plt.plot(x, scoring_function(x, lin_exp_boundary=0.5, doubling_rate=0.1))
plt.title('Scoring Function')
plt.xlabel('Test Accuracy')
plt.ylabel('Score')
plt.show()
